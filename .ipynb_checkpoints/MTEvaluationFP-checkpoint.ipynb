# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('ndata.csv')

# %%
data
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
x = data['itemDescription'].value_counts()

# %%
x
# Out:
# whole milk               2502
# other vegetables         1898
# rolls/buns               1716
# soda                     1514
# yogurt                   1334
#                          ...
# rubbing alcohol             5
# bags                        4
# baby cosmetics              3
# kitchen utensil             1
# preservation products       1
# Name: itemDescription, Length: 167, dtype: int64

# %%
A = data['itemDescription'].value_counts().sort_values(ascending=False)[:10]

# %%
A
# Out:
# whole milk          2502
# other vegetables    1898
# rolls/buns          1716
# soda                1514
# yogurt              1334
# root vegetables     1071
# tropical fruit      1032
# bottled water        933
# sausage              924
# citrus fruit         812
# Name: itemDescription, dtype: int64

# %%
A.columns=['Products','Quantity']

# %%
A.head()
# Out:
# whole milk          2502
# other vegetables    1898
# rolls/buns          1716
# soda                1514
# yogurt              1334
# Name: itemDescription, dtype: int64

# %%
import seaborn as sns

# %%
sns.barplot(x='A[0]',y='A[1]',data=A);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 sns.barplot(x='A[0]',y='A[1]',data=A)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2753, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2750 if estimator is len:
#    2751     estimator = "size"
# -> 2753 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2754                       estimator, errorbar, n_boot, units, seed,
#    2755                       orient, color, palette, saturation,
#    2756                       width, errcolor, errwidth, capsize, dodge)
#    2758 if ax is None:
#    2759     ax = plt.gca()
#
# ...

# %% [markdown]
# Apriori Algorithm
# It is an algo that uses frequent itemset to generate association rules. It is based on the concept that a subset of a frequent itemset must also be a frequent itemset.
#
# Support : It is the frequency of item A or combination of item A and item B.
#
# support = freq(A,B)/N
# A and B are products
# N is total transactions
#
#
#
# Confidence : It tells us how often the items A and B occur given that A is bought.
# confidence = freq(A,B)/freq(A)
#
#
#
# Lift : It tells us the strength of the rule.
# A -> B Lift tells us how strong this associatiom rule is.
# lift = supoort/support(A) * support(B)

# %%
# !pip install mlxtend
# Out:
# ...
#      ---------------------------------------- 1.3/1.3 MB 3.6 MB/s eta 0:00:00
# ...

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
data['Quantity']=1

# %%
data
# Out:
#        Member_number        Date        itemDescription  Quantity
# 0               1808  21-07-2015         tropical fruit         1
# 1               2552  05-01-2015             whole milk         1
# 2               2300  19-09-2015              pip fruit         1
# 3               1187  12-12-2015       other vegetables         1
# 4               3037  01-02-2015             whole milk         1
# ...              ...         ...                    ...       ...
# 38760           4471  08-10-2014          sliced cheese         1
# 38761           2022  23-02-2014                  candy         1
# 38762           1097  16-04-2014               cake bar         1
# 38763           1510  03-12-2014  fruit/vegetable juice         1
# 38764           1521  26-12-2014               cat food         1
#
# [38765 rows x 4 columns]

# %%
transactions = data.groupby(['Member_number','itemDescription'])['Quantity'].sum().unstack().reset_index().set_index('Member_number')

# %%
transactions = transactions.fillna(0)

# %%
transactions
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               0.0       0.0               0.0
# 1001                               0.0       0.0               0.0
# 1002                               0.0       0.0               0.0
# 1003                               0.0       0.0               0.0
# 1004                               0.0       0.0               0.0
# ...                                ...       ...               ...
# 4996                               0.0       0.0               0.0
# 4997                               0.0       0.0               0.0
# 4998                               0.0       0.0               0.0
# 4999                               0.0       0.0               0.0
# 5000                               0.0       0.0               0.0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
def encode(x):
    if x<=0:
        return 0;
    else:
        return 1;
basket = transactions.applymap(encode)

# %%
basket
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# ...                                ...       ...               ...
# 4996                                 0         0                 0
# 4997                                 0         0                 0
# 4998                                 0         0                 0
# 4999                                 0         0                 0
# 5000                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
frequent_itemset = apriori(basket,min_support=0.06,use_colnames=True)
rules = association_rules(frequent_itemset,metric='lift',min_threshold=1)
# Out:
# C:\Users\Lakshay\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
rules
# Out:
#               antecedents               consequents  antecedent support  \
# 0            (whole milk)                    (beef)            0.458184
# 1                  (beef)              (whole milk)            0.119548
# 2      (other vegetables)            (bottled beer)            0.376603
# 3          (bottled beer)        (other vegetables)            0.158799
# 4            (rolls/buns)            (bottled beer)            0.349666
# ..                    ...                       ...                 ...
# 153  (rolls/buns, yogurt)              (whole milk)            0.111339
# 154  (whole milk, yogurt)              (rolls/buns)            0.150590
# 155          (rolls/buns)      (whole milk, yogurt)            0.349666
# 156          (whole milk)      (rolls/buns, yogurt)            0.458184
# 157              (yogurt)  (rolls/buns, whole milk)            0.282966
#
#      consequent support   support  confidence      lift  leverage  conviction
# ...

# %%
rules[(rules['confidence']>0.4)]
# Out:
#                         antecedents         consequents  antecedent support  \
# 1                            (beef)        (whole milk)            0.119548
# 3                    (bottled beer)  (other vegetables)            0.158799
# 7                    (bottled beer)        (whole milk)            0.158799
# 9                   (bottled water)  (other vegetables)            0.213699
# 14                  (bottled water)        (whole milk)            0.213699
# 18                    (brown bread)        (whole milk)            0.135967
# 21                         (butter)        (whole milk)            0.126475
# 22                    (canned beer)  (other vegetables)            0.165213
# 24                    (canned beer)        (rolls/buns)            0.165213
# 26                    (canned beer)        (whole milk)            0.165213
# 29                   (citrus fruit)  (other vegetables)            0.185480
# ...

# %%
rules[(rules['confidence']>0.4)& (rules['lift']>1)]
# Out:
#                         antecedents         consequents  antecedent support  \
# 1                            (beef)        (whole milk)            0.119548
# 3                    (bottled beer)  (other vegetables)            0.158799
# 7                    (bottled beer)        (whole milk)            0.158799
# 9                   (bottled water)  (other vegetables)            0.213699
# 14                  (bottled water)        (whole milk)            0.213699
# 18                    (brown bread)        (whole milk)            0.135967
# 21                         (butter)        (whole milk)            0.126475
# 22                    (canned beer)  (other vegetables)            0.165213
# 24                    (canned beer)        (rolls/buns)            0.165213
# 26                    (canned beer)        (whole milk)            0.165213
# 29                   (citrus fruit)  (other vegetables)            0.185480
# ...

# %%
rules[(rules['confidence']>0.4)& (rules['lift']>1)][:10]
# Out:
#         antecedents         consequents  antecedent support  \
# 1            (beef)        (whole milk)            0.119548
# 3    (bottled beer)  (other vegetables)            0.158799
# 7    (bottled beer)        (whole milk)            0.158799
# 9   (bottled water)  (other vegetables)            0.213699
# 14  (bottled water)        (whole milk)            0.213699
# 18    (brown bread)        (whole milk)            0.135967
# 21         (butter)        (whole milk)            0.126475
# 22    (canned beer)  (other vegetables)            0.165213
# 24    (canned beer)        (rolls/buns)            0.165213
# 26    (canned beer)        (whole milk)            0.165213
#
#     consequent support   support  confidence      lift  leverage  conviction
# 1             0.458184  0.064135    0.536481  1.170886  0.009360    1.168919
# 3             0.376603  0.068497    0.431341  1.145345  0.008692    1.096257
# ...
