# %% [markdown]
# # Importing the required libraries

# %%
import numpy as np 
import pandas as pd    
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import mlxtend as ml
print('MXTend Version: %s' % ml.__version__)
print('Pandas Version: %s' % pd.__version__)
print('Numpy Version: %s' % np.__version__)
# Out:
# MXTend Version: 0.21.0
# Pandas Version: 1.4.4
# Numpy Version: 1.21.5

# %% [markdown]
# # Reading of data and removing unwanted columns

# %%
df = pd.read_csv('ds2.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %% [markdown]
# # Apriori Algorithm

# %% [markdown]
# Apriori Algorithm It is an algo that uses frequent itemset to generate association rules. It is based on the concept that a subset of a frequent itemset must also be a frequent itemset. In our case, where {apple, unicorn, yoghurt} is frequent then {apple,yoghurt} is frequent. Whereas {apple,unicorn} is not frequent, then {apple,unicorn,yoghurt} is not frequent.
#
# Support : A simple way to control complexity is to place a constraint that such rules must apply to some minimum percentage of the data. It is the frequency of item A or combination of item A and item B.
#     support = freq(A,B)/N A and B are products N is total transactions
# Confidence : The probability that B occurs when A; it is p(B|A), which in association mining. It tells us how often the items A and B occur given that A is bought.
#     confidence = freq(A,B)/freq(A)
# Lift : The co-occurrence of A and B is the probability that we actually see the two together, compared to the probability that we would see the two together if they were unrelated to (independent of) each other. It tells us the strength of the rule. A -> B Lift tells us how strong this associatiom rule is.
#     lift = supoort/support(A) * support(B)
# Leverage : alternative is to look at the difference between these quantities rather than their ratio.
# Conviction : measure to ascertain the direction of the rule. Unlike lift, conviction is sensitive to the rule direction.

# %% [markdown]
# # Using Apriori for generating frequent itemsets

# %% [markdown]
# using the use_colnames=True parameter within the apriori algorithm, we switch from items(products) numbers to item(product) names.

# %%
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
frequent_itemsets
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Eggs, Kidney Beans)
# 6       0.6                (Eggs, Onion)
# 7       0.6         (Milk, Kidney Beans)
# 8       0.6        (Onion, Kidney Beans)
# 9       0.6       (Yogurt, Kidney Beans)
# 10      0.6  (Eggs, Onion, Kidney Beans)

# %% [markdown]
# Creating the Association Rules table according to the confidence metric with min_threshold of 0.8 .

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.8)
rules
# Out:
#              antecedents           consequents  antecedent support  \
# 0                 (Eggs)        (Kidney Beans)                 0.8
# 1         (Kidney Beans)                (Eggs)                 1.0
# 2                (Onion)                (Eggs)                 0.6
# 3                 (Milk)        (Kidney Beans)                 0.6
# 4                (Onion)        (Kidney Beans)                 0.6
# 5               (Yogurt)        (Kidney Beans)                 0.6
# 6          (Eggs, Onion)        (Kidney Beans)                 0.6
# 7  (Onion, Kidney Beans)                (Eggs)                 0.6
# 8                (Onion)  (Eggs, Kidney Beans)                 0.6
#
#    consequent support  support  confidence  lift  leverage  conviction
# 0                 1.0      0.8         1.0  1.00      0.00         inf
# 1                 0.8      0.8         0.8  1.00      0.00         1.0
# 2                 0.8      0.6         1.0  1.25      0.12         inf
# ...

# %% [markdown]
# Adding the number of items in the antecedents and consequents parts

# %%
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules["consequents_len"] = rules["consequents"].apply(lambda x: len(x))
rules
# Out:
#               antecedents            consequents  antecedent support  \
# 0                  (Eggs)         (Kidney Beans)                 0.8
# 1          (Kidney Beans)                 (Eggs)                 1.0
# 2                  (Eggs)                (Onion)                 0.8
# 3                 (Onion)                 (Eggs)                 0.6
# 4                  (Milk)         (Kidney Beans)                 0.6
# 5          (Kidney Beans)                 (Milk)                 1.0
# 6                 (Onion)         (Kidney Beans)                 0.6
# 7          (Kidney Beans)                (Onion)                 1.0
# 8                (Yogurt)         (Kidney Beans)                 0.6
# 9          (Kidney Beans)               (Yogurt)                 1.0
# 10          (Eggs, Onion)         (Kidney Beans)                 0.6
# 11   (Eggs, Kidney Beans)                (Onion)                 0.8
# 12  (Onion, Kidney Beans)                 (Eggs)                 0.6
# ...

# %% [markdown]
# # Calculating time complexity of Apriori Algorithm

# %%
# %timeit apriori(df, min_support=0.6)
# Out:
# 2.75 ms ± 48 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Confidence versus Support graph for rules

# %%
sns.scatterplot(x = "support", y = "confidence", data = rules)
plt.show()

# %% [markdown]
# Creating parallel coordinates plot for rules

# %%
from pandas.plotting import parallel_coordinates
def rules_to_coordinates(rules):
    rules['antecedent'] = rules['antecedents'].apply(lambda antecedent:list(antecedent)[0])
    rules['consequent'] = rules['consequents'].apply(lambda consequent:list(consequent)[0])
    rules['rule'] = rules.index
    return rules[['antecedent','consequent','rule']]

# %%
# Convert rules into coordinates suitable for use in a parallel coordinates plot
coords = rules_to_coordinates(rules)
# Generate parallel coordinates plot
plt.figure(figsize=(4,8))
parallel_coordinates(coords, 'rule',colormap = 'ocean')
plt.legend([])
plt.show()

# %% [markdown]
# Creating the Association Rules table according to the support metric with min_threshold of 0.5 .

# %%
rules1 = association_rules(frequent_itemsets, metric="support", min_threshold=0.5)
rules1
# Out:
#               antecedents            consequents  antecedent support  \
# 0                  (Eggs)         (Kidney Beans)                 0.8
# 1          (Kidney Beans)                 (Eggs)                 1.0
# 2                  (Eggs)                (Onion)                 0.8
# 3                 (Onion)                 (Eggs)                 0.6
# 4                  (Milk)         (Kidney Beans)                 0.6
# 5          (Kidney Beans)                 (Milk)                 1.0
# 6                 (Onion)         (Kidney Beans)                 0.6
# 7          (Kidney Beans)                (Onion)                 1.0
# 8                (Yogurt)         (Kidney Beans)                 0.6
# 9          (Kidney Beans)               (Yogurt)                 1.0
# 10          (Eggs, Onion)         (Kidney Beans)                 0.6
# 11   (Eggs, Kidney Beans)                (Onion)                 0.8
# 12  (Onion, Kidney Beans)                 (Eggs)                 0.6
# ...

# %% [markdown]
# Adding the number of items in the antecedents and consequents parts

# %%
rules1["antecedent_len"] = rules1["antecedents"].apply(lambda x: len(x))
rules1["consequents_len"] = rules1["consequents"].apply(lambda x: len(x))
rules1
# Out:
#               antecedents            consequents  antecedent support  \
# 0                  (Eggs)         (Kidney Beans)                 0.8
# 1          (Kidney Beans)                 (Eggs)                 1.0
# 2                  (Eggs)                (Onion)                 0.8
# 3                 (Onion)                 (Eggs)                 0.6
# 4                  (Milk)         (Kidney Beans)                 0.6
# 5          (Kidney Beans)                 (Milk)                 1.0
# 6                 (Onion)         (Kidney Beans)                 0.6
# 7          (Kidney Beans)                (Onion)                 1.0
# 8                (Yogurt)         (Kidney Beans)                 0.6
# 9          (Kidney Beans)               (Yogurt)                 1.0
# 10          (Eggs, Onion)         (Kidney Beans)                 0.6
# 11   (Eggs, Kidney Beans)                (Onion)                 0.8
# 12  (Onion, Kidney Beans)                 (Eggs)                 0.6
# ...

# %%
Confidence versus Support graph for rules1

# %%
sns.scatterplot(x = "support", y = "confidence", data = rules1)
plt.show()

# %% [markdown]
# Creating parallel coordinates plot for rules1

# %%
# Convert rules into coordinates suitable for use in a parallel coordinates plot
coords = rules_to_coordinates(rules1)
# Generate parallel coordinates plot
plt.figure(figsize=(4,8))
parallel_coordinates(coords, 'rule',colormap = 'ocean')
plt.legend([])
plt.show()
